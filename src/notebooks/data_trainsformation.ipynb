# %% [markdown]
# ### The ordinal categorical data is given as a numbers here, which can create a problem while reading from the UI, the Front End Engineer will need to know, which value corresponds to which integer. We better handle this ourselves here.
#
# This will help us in Data Visualization in the Future as Well***

# %%
# Library for Data Manipulation
import numpy as np
import pandas as pd

# Library for Statistical Modelling
from sklearn.preprocessing import LabelEncoder

# Library for Ignore the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# Set the display option to show all columns
pd.set_option('display.max_columns', None)

# %matplotlib inline

# %%
# Load the dataset into the dataframe
employee_data = pd.read_csv('../data/IBM-HR-Analytics-Employee-Attrition-and-Performance.csv')

employee_data['StockOptionLevel'].unique()
# Out:
# array([0, 1, 3, 2], dtype=int64)

# %% [markdown]
# Modifying the Catergorical Ordinal Columns

# %%
employee_data["Education"] = employee_data["Education"].replace(
    {1: "Below College", 2: "College", 3: "Bachelor", 4: "Master", 5: "Doctor"}
)
employee_data["EnvironmentSatisfaction"] = employee_data[
    "EnvironmentSatisfaction"
].replace({1: "Low", 2: "Medium", 3: "High", 4: "Very High"})
employee_data["JobInvolvement"] = employee_data["JobInvolvement"].replace(
    {1: "Low", 2: "Medium", 3: "High", 4: "Very High"}
)
employee_data["JobLevel"] = employee_data["JobLevel"].replace(
    {
        1: "Entry Level",
        2: "Junior Level",
        3: "Mid Level",
        4: "Senior Level",
        5: "Executive Level",
    }
)
employee_data["JobSatisfaction"] = employee_data["JobSatisfaction"].replace(
    {1: "Low", 2: "Medium", 3: "High", 4: "Very High"}
)
employee_data["PerformanceRating"] = employee_data["PerformanceRating"].replace(
    {1: "Low", 2: "Good", 3: "Excellent", 4: "Outstanding"}
)
employee_data["RelationshipSatisfaction"] = employee_data[
    "RelationshipSatisfaction"
].replace({1: "Low", 2: "Medium", 3: "High", 4: "Very High"})
employee_data["WorkLifeBalance"] = employee_data["WorkLifeBalance"].replace(
    {1: "Bad", 2: "Good", 3: "Better", 4: "Best"}
)
employee_data["StockOptionLevel"] = employee_data["StockOptionLevel"].replace(
    {
        0: "No Stock Options",
        1: "Low Stock Options",
        2: "Medium Stock Options",
        3: "High Stock Options",
    }
)

# %%
employee_data[['StockOptionLevel']].head()
# Out:
#     StockOptionLevel
# 0   No Stock Options
# 1  Low Stock Options
# 2   No Stock Options
# 3   No Stock Options
# 4  Low Stock Options

# %% [markdown]
# There is another Ordinal Column -> "NumCompaniesWorked". Because it can take discrete number of values & has a natural order to it. But No need to change this.

# %%
employee_data.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 85     56        No      Travel_Rarely       1400  Research & Development
# 955    55        No      Travel_Rarely        282  Research & Development
# 1170   27        No  Travel_Frequently        591  Research & Development
# 1420   41        No      Travel_Rarely        642  Research & Development
# 74     36        No      Travel_Rarely        132  Research & Development
#
#       DistanceFromHome Education EducationField  EmployeeCount  \
# 85                   7  Bachelor  Life Sciences              1
# 955                  2   College        Medical              1
# 1170                 2  Bachelor        Medical              1
# 1420                 1  Bachelor  Life Sciences              1
# 74                   6  Bachelor  Life Sciences              1
#
#       EmployeeNumber EnvironmentSatisfaction  Gender  HourlyRate  \
# 85               112               Very High    Male          49
# 955             1336               Very High  Female          58
# 1170            1648               Very High    Male          87
# 1420            1999               Very High    Male          76
# 74                97                  Medium  Female          55
#
#      JobInvolvement         JobLevel                 JobRole JobSatisfaction  \
# 85              Low        Mid Level  Manufacturing Director       Very High
# 955             Low  Executive Level                 Manager            High
# 1170           High      Entry Level      Research Scientist       Very High
# 1420           High      Entry Level      Research Scientist       Very High
# 74        Very High      Entry Level   Laboratory Technician       Very High
#
#      MaritalStatus  MonthlyIncome  MonthlyRate  NumCompaniesWorked Over18  \
# 85          Single           7260        21698                   4      Y
# 955        Married          19187         6992                   4      Y
# 1170        Single           2580         6297                   2      Y
# 1420       Married           2782        21412                   3      Y
# 74         Married           3038        22002                   3      Y
#
#      OverTime  PercentSalaryHike PerformanceRating RelationshipSatisfaction  \
# 85         No                 11         Excellent                      Low
# 955        No                 14         Excellent                Very High
# 1170       No                 13         Excellent                     High
# 1420       No                 22       Outstanding                      Low
# 74         No                 12         Excellent                   Medium
#
#       StandardHours   StockOptionLevel  TotalWorkingYears  \
# 85               80   No Stock Options                 37
# 955              80  Low Stock Options                 23
# 1170             80   No Stock Options                  6
# 1420             80  Low Stock Options                 12
# 74               80   No Stock Options                  5
#
#       TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 85                        3            Good               6
# 955                       5          Better              19
# 1170                      0            Good               4
# 1420                      3          Better               5
# 74                        3          Better               1
#
#       YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager
# 85                     4                        0                     2
# 955                    9                        9                    11
# 1170                   2                        1                     2
# 1420                   3                        1                     0
# 74                     0                        0                     0

# %% [markdown]
# Removing Un-necessary Columns from the Table

# %%
employee_data.drop(['EmployeeCount', 'EmployeeNumber', 'Over18'], axis=1, inplace=True)
employee_data.sample(5)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 364    37        No      Travel_Rarely        921  Research & Development
# 753    39        No  Travel_Frequently        945  Research & Development
# 1088   42        No      Travel_Rarely       1210  Research & Development
# 957    40        No         Non-Travel        458  Research & Development
# 124    31       Yes      Travel_Rarely        249                   Sales
#
#       DistanceFromHome Education EducationField EnvironmentSatisfaction  \
# 364                 10  Bachelor        Medical                    High
# 753                 22  Bachelor        Medical               Very High
# 1088                 2  Bachelor        Medical                    High
# 957                 16   College  Life Sciences                    High
# 124                  6    Master  Life Sciences                  Medium
#
#       Gender  HourlyRate JobInvolvement      JobLevel                 JobRole  \
# 364   Female          98           High   Entry Level   Laboratory Technician
# 753   Female          82           High     Mid Level  Manufacturing Director
# 1088    Male          68         Medium   Entry Level   Laboratory Technician
# 957     Male          74           High   Entry Level      Research Scientist
# 124     Male          76            Low  Junior Level         Sales Executive
#
#      JobSatisfaction MaritalStatus  MonthlyIncome  MonthlyRate  \
# 364              Low       Married           3452        17663
# 753              Low        Single          10880         5083
# 1088          Medium       Married           4841        24052
# 957             High      Divorced           3544         8532
# 124             High       Married           6172        20739
#
#       NumCompaniesWorked OverTime  PercentSalaryHike PerformanceRating  \
# 364                    6       No                 20       Outstanding
# 753                    1      Yes                 13         Excellent
# 1088                   4       No                 14         Excellent
# 957                    9       No                 16         Excellent
# 124                    4      Yes                 18         Excellent
#
#      RelationshipSatisfaction  StandardHours   StockOptionLevel  \
# 364                    Medium             80  Low Stock Options
# 753                      High             80   No Stock Options
# 1088                   Medium             80  Low Stock Options
# 957                    Medium             80  Low Stock Options
# 124                    Medium             80   No Stock Options
#
#       TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 364                  17                      3          Better
# 753                  21                      2          Better
# 1088                  4                      3          Better
# 957                   6                      0          Better
# 124                  12                      3            Good
#
#       YearsAtCompany  YearsInCurrentRole  YearsSinceLastPromotion  \
# 364                5                   4                        0
# 753               21                   6                        2
# 1088               1                   0                        0
# 957                4                   2                        0
# 124                7                   7                        7
#
#       YearsWithCurrManager
# 364                      3
# 753                      8
# 1088                     0
# 957                      0
# 124                      7

# %%
train_df = employee_data.sample(1)
target = train_df["Attrition"]
train_df.drop(["Attrition"], axis=1, inplace=True)
train_dict = train_df.to_dict(orient="records")
print(train_dict[0])
# Out:
# {'Age': 48, 'BusinessTravel': 'Travel_Frequently', 'DailyRate': 365, 'Department': 'Research & Development', 'DistanceFromHome': 4, 'Education': 'Doctor', 'EducationField': 'Medical', 'EnvironmentSatisfaction': 'High', 'Gender': 'Male', 'HourlyRate': 89, 'JobInvolvement': 'Medium', 'JobLevel': 'Senior Level', 'JobRole': 'Manager', 'JobSatisfaction': 'Very High', 'MaritalStatus': 'Married', 'MonthlyIncome': 15202, 'MonthlyRate': 5602, 'NumCompaniesWorked': 2, 'OverTime': 'No', 'PercentSalaryHike': 25, 'PerformanceRating': 'Outstanding', 'RelationshipSatisfaction': 'Medium', 'StandardHours': 80, 'StockOptionLevel': 'Low Stock Options', 'TotalWorkingYears': 23, 'TrainingTimesLastYear': 3, 'WorkLifeBalance': 'Better', 'YearsAtCompany': 2, 'YearsInCurrentRole': 2, 'YearsSinceLastPromotion': 2, 'YearsWithCurrManager': 2}

# %% [markdown]
# Export the df to a csv file

# %%
# Assuming employee_data is your DataFrame
employee_data.to_csv('../data/refined_employee_data.csv', index=False)
